# %%
import pandas as pd

# %%
service_calls = pd.read_csv("All Service Calls.csv")
Cosa_address = "https://opendata-cosagis.opendata.arcgis.com/api/download/v1/items/35fc212b7d944dd0ac7527d6d839729e/csv?layers=15"
Cosa_address = pd.read_csv(Cosa_address)

# %%
service_calls.head(10)
# Out:
#    _id                   Category      CASEID OPENEDDATETIME    SLA_Date  \
# 0    1  Traffic Signals and Signs  1014001765      11/3/2017   9/22/2021
# 1    2       Solid Waste Services  1014303843       3/7/2018   3/16/2018
# 2    3  Traffic Signals and Signs  1014504120      5/11/2018  10/31/2018
# 3    4  Traffic Signals and Signs  1014549690      5/27/2018  11/15/2018
# 4    5       Solid Waste Services  1014569491       6/3/2018   6/11/2018
# 5    6                   Graffiti  1014633806      6/25/2018   9/19/2018
# 6    7  Traffic Signals and Signs  1014679731      7/11/2018  11/15/2018
# 7    8  Traffic Signals and Signs  1014680784      7/11/2018  11/16/2018
# 8    9  Traffic Signals and Signs  1014702023      7/19/2018    1/4/2019
# 9   10  Traffic Signals and Signs  1014709576      7/22/2018    1/8/2019
#
#   CLOSEDDATETIME Late (Yes/No)                    Dept  \
# 0      3/16/2023           YES            Public Works
# ...

# %%
Cosa_address.head(10)
# Out:
#    OBJECTID  AddrKey  HouseNumber  StreetNameID PreDirection    Name  \
# 0         1   500855          232       67978.0           E   DREXEL
# 1         2   500878         1127       73434.0          NaN   NOLAN
# 2         3   500887          119       69698.0          NaN  GORMAN
# 3         4   513662          124       80868.0          NaN   KLEIN
# 4         5   513670          135       66132.0          NaN    CASS
# 5         6   513682          115       67954.0           E   BAYLOR
# 6         7   540792          115       63780.0          NaN   ABISO
# 7         8   540794          125       63780.0          NaN   ABISO
# 8         9   540799          228       64316.0          NaN    ARGO
# 9        10   540801          220       64316.0          NaN    ARGO
#
#   AbbrevType PostDirection  TownCode  CouncilDist     XCoord      YCoord  \
# 0     AVE              NaN       0.0            3  2137244.6  13693542.6
# ...

# %%
Cosa_address.dtypes
# Out:
# OBJECTID           int64
# AddrKey            int64
# HouseNumber        int64
# StreetNameID     float64
# PreDirection      object
# Name              object
# AbbrevType        object
# PostDirection     object
# TownCode         float64
# CouncilDist        int64
# XCoord           float64
# YCoord           float64
# EntryDate         object
# ModifiedDate      object
# Address           object
# ExpiredDate      float64
# x                float64
# y                float64
# dtype: object

# %%
service_calls.drop_duplicates()
# Out:
#            _id                   Category      CASEID OPENEDDATETIME  \
# 0            1  Traffic Signals and Signs  1014001765      11/3/2017
# 1            2       Solid Waste Services  1014303843       3/7/2018
# 2            3  Traffic Signals and Signs  1014504120      5/11/2018
# 3            4  Traffic Signals and Signs  1014549690      5/27/2018
# 4            5       Solid Waste Services  1014569491       6/3/2018
# ...        ...                        ...         ...            ...
# 606056  606057                    Animals  1019442050       3/1/2024
# 606057  606058                    Animals  1019442051       3/1/2024
# 606058  606059                    Animals  1019442052       3/1/2024
# 606059  606060                    Animals  1019442053       3/1/2024
# 606060  606061       Property Maintenance  1019442054       3/1/2024
#
#           SLA_Date CLOSEDDATETIME Late (Yes/No)                    Dept  \
# ...

# %%
service_calls.shape
# Out:
# (606061, 18)

# %%
service_calls['Category'].unique()
# Out:
# array(['Traffic Signals and Signs', 'Solid Waste Services', 'Graffiti',
#        'Streets & Infrastructure', 'Animals', 'Historic Preservation',
#        'Parks', 'Information', 'Dockless Vehicle', 'Property Maintenance',
#        'Health & Sanitation'], dtype=object)

# %%
service_calls['Category'].value_counts()
# Out:
# Property Maintenance         198332
# Solid Waste Services         193882
# Animals                      118214
# Streets & Infrastructure      38164
# Traffic Signals and Signs     28875
# Parks                         14298
# Health & Sanitation            5927
# Information                    5005
# Dockless Vehicle               2509
# Graffiti                        479
# Historic Preservation           376
# Name: Category, dtype: int64

# %%
# Assuming service_calls is your DataFrame containing the data
property_maintenance_df = service_calls[service_calls['Category'] == 'Property Maintenance']

property_maintenance_df
# Out:
#            _id              Category      CASEID OPENEDDATETIME   SLA_Date  \
# 4632      4633  Property Maintenance  1016424267      10/1/2020  12/8/2020
# 4634      4635  Property Maintenance  1016424292      10/1/2020  12/8/2020
# 4637      4638  Property Maintenance  1016424797      10/1/2020  10/6/2020
# 4638      4639  Property Maintenance  1016424804      10/1/2020  10/6/2020
# 4639      4640  Property Maintenance  1016424839      10/1/2020  12/8/2020
# ...        ...                   ...         ...            ...        ...
# 606031  606032  Property Maintenance  1019442020       3/1/2024   5/8/2024
# 606049  606050  Property Maintenance  1019442043       3/1/2024   5/8/2024
# 606050  606051  Property Maintenance  1019442044       3/1/2024   5/8/2024
# 606052  606053  Property Maintenance  1019442046       3/1/2024   5/8/2024
# 606060  606061  Property Maintenance  1019442054       3/1/2024   5/8/2024
#
# ...

# %%
service_calls['TYPENAME'].unique()
# Out:
# array(['Signal Timing Modification By Engineer',
#        'Additional Cart Request', 'Traffic Signal New Request',
#        'Damaged Cart', 'Traffic Signal Graffiti',
#        'Sign Fabrication - Internal', 'Left-Turn Signal New Request',
#        'Engineering Design', 'Signal Timing Modification',
#        'All-Way Stop Study', 'Animal Permits Request',
#        'Sign Installations SMO (NEW)', 'Aggressive Animal(Non-Critical)',
#        'Animal Neglect', 'Traffic Sign Faded',
#        'Bicycle Lane/Route New Request', 'Working WO Permit',
#        'Public Nuisance(Own Animal)', 'Pedestrian Signal - New Request',
#        'Aggressive Animal(Multiple Requests)',
#        'Aggressive Animal(Critical)', 'Injured Animal(Critical)',
#        'Animals(Stray Animal)', 'Cruelty-Neglect(Animal Cruelty)',
#        'Animals(Aggressive Non-Critical)',
#        'Cruelty Neglect(Animal Neglect)', 'Animals(Aggressive Critical)',
#        'Traffic Signals (New Signal)', 'Trapped/Confined',
# ...

# %%
service_calls['TYPENAME'].value_counts()
# Out:
# Overgrown Yard/Trash                             64269
# No Pickup                                        61561
# Animals(Aggressive Non-Critical)                 30784
# Dead Animal Pick Up                              30414
# Carts(Damaged Cart)                              30042
#                                                  ...
# Injured Animal(Critical)                             1
# Aggressive Animal(Multiple Requests)                 1
# Sign Fabrication - Internal                          1
# Sanitation (Natural Areas-Port Toilet Repair)        1
# Storm Damage                                         1
# Name: TYPENAME, Length: 262, dtype: int64

# %%
##api for san antonio districs?
